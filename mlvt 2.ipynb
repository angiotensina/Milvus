# %%
# -*- coding: utf-8 -*-
######################### IMPORTAR LIBRERÍAS #########################
import os
from dotenv import load_dotenv, find_dotenv
from pymilvus import connections, db, CollectionSchema, FieldSchema, DataType, Collection, MilvusClient

# import Langchain modules
from langchain.agents import tool
from langchain_text_splitters import CharacterTextSplitter
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableParallel, RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain_core.documents import Document
from langchain_community.document_loaders import TextLoader, PyPDFDirectoryLoader
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_milvus.vectorstores import Milvus

######################### VARIABLES DE ENTORNO #########################
QUERY = "¿Qué es el Parkinson?"

LLM_MODEL = "gpt-4o-mini"
EMBEDDING_MODEL = "text-embedding-3-large"
DIMENSION_EMBEDDING = 3072

INPUT_FILE = "parkinson_gpt.txt"
BD_NAME = "Joaquin_DB90"
COLLECTION_NAME = "Joaquin_Col"

URI_CONNECTION = "http://localhost:19530"
HOST = "localhost"
PORT = 19530

######################### OBTENER API KEY DE OPENAI #########################
# Carga las variables de entorno desde un archivo .env
load_dotenv(find_dotenv(), override=True)

# Obtiene la API key de OpenAI desde las variables de entorno
api_key_openAI = os.environ.get("OPENAI_API_KEY")
print(api_key_openAI)
# Out:
# sk-proj-bLpI4ExJAbHOa2n9R3DaT3BlbkFJBI6fQ7K2ExHIlj8EJPUk

# %%
######################### CARGAR EL DOCUMENTO #########################

# load the document and split it into chunks

# loader = PyPDFDirectoryLoader("./folder")
loader = TextLoader(INPUT_FILE)
documents = loader.load()

# split it into chunks
text_splitter = CharacterTextSplitter(
    separator="\n\n", 
    chunk_overlap=0
    )
docs = text_splitter.split_documents(documents)

######################## ADDING METADATA TO DOCUMENTS ########################
# Adding metadata to documents
for i, doc in enumerate(docs):
    doc.metadata["chunk"] = i
    doc.metadata["Title"] = "Parkinson"
    doc.metadata["Capitulo"] = "30"
    doc.metadata["author"] = "Joaquin Chamorro"

# %%
print(documents)
# Out:
# [Document(metadata={'source': 'parkinson_gpt.txt'}, page_content='# Trastornos del Movimiento\n\nBlair Ford, MD  \nHoward Geyer, MD, PhD  \nSusan B. Bressman, MD\n\nLos trastornos del movimiento son condiciones que producen ya sea una reducción o un exceso de movimiento. Los trastornos neurológicos que resultan en una escasez o lentitud de movimiento se denominan trastornos hipocinéticos. La categoría de trastornos hipocinéticos está representada por la enfermedad de Parkinson y otras causas de parkinsonismo. Los trastornos hipercinéticos se caracterizan por movimientos excesivos e involuntarios. Los trastornos hipercinéticos generalmente pueden clasificarse en una de las cinco categorías principales de movimientos anormales: distonía, corea, temblor, mioclonía o tics.\n\nLos movimientos anormales pueden ser difíciles de reconocer o categorizar debido a su apariencia inusual, complejidad, sutileza o variabilidad. Los especialistas en trastornos del movimiento tienden a aislar o reducir los movimientos anormales a sus componentes unitarios, pero a menudo es el patrón del movimiento y su distribución corporal lo que proporciona la pista diagnóstica más importante. Además, muchas enfermedades causan movimientos anormales que pueden encajar en dos o más categorías de fenómenos de movimiento anormal. La Tabla 15-1 proporciona descripciones de las principales categorías de trastornos del movimiento.\n\nExisten muchos otros tipos de movimientos anormales que no encajan fácilmente en una simple clasificación de fenomenología. La atetosis, que significa "postura fija", se utilizó por primera vez en referencia a una lesión postanóxica del nacimiento para denotar un movimiento "fibrilante" de los miembros y los dígitos. En el uso moderno, el término describe un movimiento lento, continuo y retorcido que tiene similitudes tanto con la corea como con la distonía. El balismo se refiere a movimientos de gran amplitud y aleatorios de los miembros y representa una forma proximal de corea. El balismo unilateral se denomina hemibalismo y es más comúnmente causado por un infarto del núcleo subtalámico contralateral. La acatisia, que significa "incapacidad para quedarse quieto", describe una inquietud interna y una intolerancia a permanecer quieto, acompañada de movimientos repetitivos de inquietud, retorcimiento y balanceo.\n\nMuchos, pero no todos, los trastornos del movimiento resultan de una función desordenada de los ganglios basales, un grupo de núcleos subcorticales interconectados. Los ganglios basales comprenden la sustancia negra, el putamen, el caudado, el globo pálido y el núcleo subtalámico, formando un sistema de control motor extrapiramidal con extensas conexiones recíprocas al tálamo, la corteza, el tronco encefálico y el cerebelo.\n\nMuchos trastornos del movimiento se tratan sintomáticamente, utilizando agentes que suprimen o reducen los movimientos no deseados, pero en algunos casos existen terapias que abordan la patofisiología subyacente. En las últimas décadas, las opciones de tratamiento, incluidas las aproximaciones farmacológicas y quirúrgicas, se han expandido gracias a los avances en ciencias básicas como la genética y la neurofisiología. En las secciones que siguen, se describen los principales síndromes de trastornos del movimiento, con énfasis en el diagnóstico clínico y el tratamiento.\n\n## Enfermedad de Parkinson y Parkinsonismo\n\n### Esenciales del Diagnóstico\n\n- Temblor en reposo\n- Bradicinesia\n- Rigidez\n- Pérdida de reflejos posturales\n- Postura flexionada\n- Congelación\n\n### Consideraciones Generales\n\nEl término parkinsonismo puede usarse cuando un paciente exhibe uno o más de los siguientes hallazgos: temblor en reposo, bradicinesia, rigidez, pérdida de reflejos posturales, postura flexionada y congelación. Dos de estos hallazgos, al menos uno de los cuales debe ser temblor en reposo o bradicinesia, son necesarios para hacer un diagnóstico de parkinsonismo definitivo. La enfermedad de Parkinson (EP) ...

# %%
######################### CONECTAR A MILVUS #########################

uri = URI_CONNECTION

client = MilvusClient(
    uri=uri,
    token="joaquin:chamorro"
)

connections.connect(alias="default", host=HOST, port=PORT)

######################### CREAR LA BASE DE DATOS EN MILVUS #########################

db_name = BD_NAME
if db_name not in db.list_database():
    db.create_database(db_name, using="default")
    db.using_database(db_name, using="default")
else:
    db.using_database(db_name, using="default")

print(f"Conectado a la base de datos {db_name}")
# Out:
# Conectado a la base de datos Joaquin_DB90

# %%
######################### CREAR LA COLECCIÓN EN MILVUS #########################
collection_name = COLLECTION_NAME
dimension = DIMENSION_EMBEDDING  # Especifica la dimensión del vector

######################### GUARDAR LOS VECTORES EN MILVUS - VECTORSTORE #########################
#vector_store = Milvus()

# Crear la función de embeddings de código abierto
embeddings = OpenAIEmbeddings(model="text-embedding-3-large", api_key=api_key_openAI)

index_params = {
    "index_type": "HNSW",
    "metric_type": "COSINE",
    "params": {"M": 8, "efConstruction": 64}
}

if collection_name not in client.list_collections():
    vector_store = Milvus.from_documents(
        docs,
        embedding=embeddings,
        collection_name=collection_name,
        connection_args={"uri": uri},
        primary_field="pk",
        text_field="text",
        vector_field="vector",
        index_params=index_params,
        enable_dynamic_field=True,
        drop_old=True
    )
    print("Colección creada")
else:
    vector_store = Milvus(
        embeddings,
        collection_name=collection_name,
        connection_args={"uri": uri},
        enable_dynamic_field=True,
        primary_field="pk",
        text_field="text",
        vector_field="vector",
        index_params=index_params
    )
    print("Colección ya existe")

print(f"Conexión a Milvus-VectorStore establecida.\nConectado a colleccion: {collection_name}\n")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 18
#      11 index_params = {
#      12     "index_type": "FLAT",
#      13     "metric_type": "COSINE",
#      14     "params": {"M": 8, "efConstruction": 64}
#      15 }
#      17 if collection_name not in client.list_collections():
# ---> 18     vector_store = Milvus.from_documents(
#      19         docs,
#      20         embedding=embeddings,
#      21         collection_name=collection_name,
#      22         connection_args={"uri": uri},
#      23         primary_field="pk",
#      24         text_field="text",
#      25         vector_field="vector",
#      26         index_params=index_params,
#      27         enable_dynamic_field=True,
#      28         drop_old=True
#      29     )
#      30     print("Colección creada")
#      31 else:
#
# File ~/Desktop/milvus/env/lib/python3.12/site-packages/langchain_core/vectorstores/base.py:1058, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#    1056 texts = [d.page_content for d in documents]
#    1057 metadatas = [d.metadata for d in documents]
# -> 1058 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File ~/Desktop/milvus/env/lib/python3.12/site-packages/langchain_milvus/vectorstores/milvus.py:1183, in Milvus.from_texts(cls, texts, embedding, metadatas, collection_name, connection_args, consistency_level, index_params, search_params, drop_old, ids, **kwargs)
#    1170     auto_id = True
#    1172 vector_db = cls(
#    1173     embedding_function=embedding,
#    1174     collection_name=collection_name,
#    (...)
#    1181     **kwargs,
#    1182 )
# -> 1183 vector_db.add_texts(texts=texts, metadatas=metadatas, ids=ids)
#    1184 return vector_db
#
# File ~/Desktop/milvus/env/lib/python3.12/site-packages/langchain_milvus/vectorstores/milvus.py:717, in Milvus.add_texts(self, texts, metadatas, timeout, batch_size, ids, **kwargs)
#     715     if self.timeout:
#     716         kwargs["timeout"] = self.timeout
# --> 717     self._init(**kwargs)
#     719 insert_list: list[dict] = []
#     721 assert len(texts) == len(
#     722     embeddings
#     723 ), "Mismatched lengths of texts and embeddings."
#
# File ~/Desktop/milvus/env/lib/python3.12/site-packages/langchain_milvus/vectorstores/milvus.py:405, in Milvus._init(self, embeddings, metadatas, partition_names, replica_number, timeout)
#     403 self._extract_fields()
#     404 self._create_index()
# --> 405 self._create_search_params()
#     406 self._load(
#     407     partition_names=partition_names,
#     408     replica_number=replica_number,
#     409     timeout=timeout,
#     410 )
#
# File ~/Desktop/milvus/env/lib/python3.12/site-packages/langchain_milvus/vectorstores/milvus.py:612, in Milvus._create_search_params(self)
#     610 index_type: str = index["index_param"]["index_type"]
#     611 metric_type: str = index["index_param"]["metric_type"]
# --> 612 self.search_params = self.default_search_params[index_type]
#     613 self.search_params["metric_type"] = metric_type
#
# KeyError: 'FLAT'

# %%
print(vector_store._get_index())
print(vector_store._get_index().get("collection"))
# Out:
# {'collection': 'Joaquin_Col', 'field': 'vector', 'index_name': 'vector', 'index_param': {'index_type': 'HNSW', 'metric_type': 'COSINE', 'params': {'M': 8, 'efConstruction': 64}}}
# Joaquin_Col

# %%
######################### RECUPERAR LOS VECTORES SIMILARES - RETRIEVER #########################

query = QUERY

model = ChatOpenAI(api_key=api_key_openAI, model=LLM_MODEL)

retriever = vector_store.as_retriever(
    search_type="similarity", search_kwargs={"k": 10, "filter": {"chapter": "30"}})
    #search_type="mmr", search_kwargs={"k": 10, "fetch_k": 50})

# %%
######################### EJECUTAR EL PIPELINE #########################

template =  """
            - Contesta como un profesional medico: {context}
            - Si no se aportan documentos:
                - Menciona que no se aportan documentos
                - Responde con tu conocimiento
            - Question: {question}
            """
prompt = ChatPromptTemplate.from_template(template)
output_parser = StrOutputParser()
setup_and_retrieval = RunnableParallel(
    {"context": retriever, "question": RunnablePassthrough()})
chain = setup_and_retrieval | prompt | model | output_parser
respuesta=chain.invoke(query)

print(respuesta)
# Out:
# La enfermedad de Parkinson (EP) es un trastorno neurodegenerativo progresivo que afecta principalmente el control motor. Se caracteriza por la degeneración de las neuronas dopaminérgicas en la sustancia negra del cerebro, lo que da lugar a una disminución de la dopamina, un neurotransmisor crucial para el control del movimiento. Los síntomas motores más típicos de la EP incluyen:
#
# 1. **Temblor en reposo**: Este es un movimiento involuntario, oscilante, que generalmente comienza en una extremidad (a menudo una mano) y puede aumentar con el estrés.
# 2. **Bradicinesia**: Se refiere a la lentitud en la iniciación y ejecución de movimientos, lo que puede dificultar actividades cotidianas.
# 3. **Rigidez**: Los músculos se tensan, lo que puede causar dolor y limitar el rango de movimiento.
# 4. **Pérdida de reflejos posturales**: Esto puede resultar en inestabilidad y caídas.
# 5. **Postura flexionada**: Los pacientes a menudo tienen una postura encorvada.
# 6. **Congelación**: Sensación de que el cuerpo se "congela" y no puede moverse, especialmente al comenzar a caminar.
#
# Además de los síntomas motores, la EP también puede presentar manifestaciones no motoras, como trastornos del sueño, cambios en el estado de ánimo, y disfunciones autonómicas.
#
# La enfermedad de Parkinson es más común en personas mayores de 60 años y tiene una prevalencia que aumenta con la edad. Aunque no existe una cura, los tratamientos están disponibles para ayudar a controlar los síntomas y mejorar la calidad de vida de los pacientes. La terapia más común incluye el uso de medicamentos que aumentan los niveles de dopamina en el cerebro, como la levodopa, y otros agentes dopaminérgicos. También se pueden considerar tratamientos quirúrgicos, como la estimulación cerebral profunda, en casos avanzados.
